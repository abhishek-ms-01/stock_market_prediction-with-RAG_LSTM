# %%
import yfinance as yf
import pandas as pd

# Download stock data
data = yf.download(
    "RELIANCE.NS",
    start="2023-01-01",
    end="2024-01-01"
)

# Flatten columns if MultiIndex
if isinstance(data.columns, pd.MultiIndex):
    data.columns = data.columns.get_level_values(0)

# Save CSV
data.to_csv("../data/stock_data.csv")

print(data.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price             Close         High          Low         Open    Volume
# 2023-01-02  1175.889648  1177.304802  1163.244669  1164.066352   5316175
# 2023-01-03  1167.284668  1174.565828  1163.062148  1170.936659   7658932
# 2023-01-04  1149.709595  1169.110728  1147.632506  1167.261851   9264891
# 2023-01-05  1147.655396  1157.858149  1143.067616  1151.969321  13637099
# 2023-01-06  1158.086304  1163.130627  1149.595501  1153.407240   6349597

# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

import pandas as pd

from indicators.rsi import calculate_rsi
from indicators.macd import calculate_macd
from indicators.moving_average import calculate_ma

# Read the dataset
df = pd.read_csv("../data/stock_data.csv")

# Ensure all price columns are numeric (converts any invalid strings to NaN)
numeric_cols = ['Close', 'High', 'Low', 'Open', 'Volume']
for col in numeric_cols:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# Calculate indicators
df = calculate_rsi(df)
df = calculate_macd(df)
df = calculate_ma(df)


print(df.head())

df.to_csv("../data/final_dataset.csv", index=False)
# Out:
#    Unnamed: 0        Close         High          Low         Open    Volume  \
# 0  2023-01-02  1175.889648  1177.304802  1163.244669  1164.066352   5316175
# 1  2023-01-03  1167.284668  1174.565828  1163.062148  1170.936659   7658932
# 2  2023-01-04  1149.709595  1169.110728  1147.632506  1167.261851   9264891
# 3  2023-01-05  1147.655396  1157.858149  1143.067616  1151.969321  13637099
# 4  2023-01-06  1158.086304  1163.130627  1149.595501  1153.407240   6349597
#
#    RSI  MACD  MA_20
# 0  NaN   NaN    NaN
# 1  NaN   NaN    NaN
# 2  NaN   NaN    NaN
# 3  NaN   NaN    NaN
# 4  NaN   NaN    NaN
